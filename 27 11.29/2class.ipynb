# %%
class P:
    pass
    def f():
        print(1)
p=P()
p.n='gump'
p.a=33
p.n
p1=P()
# p1.n
p1.run=f
p1.run()
# Out:
# 'gump'
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       9 p1=P()
#      10 # p1.n
# ---> 11 p1.run=f
#      12 p1.run()
#
# NameError: name 'f' is not defined

# %%
import pandas as pd

# 1. 读取数据
df = pd.read_csv('team_attributes.csv')
# 2. 在 id 前加上 'a'
df['id'] = 'a' + df['id'].astype(str)
# 3. id 设置为索引（方便后续标签索引）
df.set_index('id', inplace=True)

print("=== 原始数据（加上a后） ===")
print(df.head())
# Out:
# === 原始数据（加上a后） ===
#     team_api_id            date  buildUpPlaySpeed buildUpPlaySpeedClass  \
# id
# a0         9930  2010/2/22 0:00                60              Balanced
# a1         9930  2014/9/19 0:00                52              Balanced
# a2         9930  2015/9/10 0:00                47              Balanced
# a3         8485  2010/2/22 0:00                70                  Fast
# a4         8485  2011/2/22 0:00                47              Balanced
#
#     buildUpPlayDribbling buildUpPlayDribblingClass  buildUpPlayPassing  \
# id
# a0                   NaN                    Little                  50
# a1                  48.0                    Normal                  56
# a2                  41.0                    Normal                  54
# a3                   NaN                    Little                  70
# a4                   NaN                    Little                  52
#
#    buildUpPlayPassingClass buildUpPlayPositioningClass  chanceCreationPassing  \
# id
# a0                   Mixed                   Organised                     60
# a1                   Mixed                   Organised                     54
# a2                   Mixed                   Organised                     54
# a3                    Long                   Organised                     70
# a4                   Mixed                   Organised                     53
#
#     ... chanceCreationShooting  chanceCreationShootingClass  \
# id  ...
# a0  ...                     55                       Normal
# a1  ...                     64                       Normal
# a2  ...                     64                       Normal
# a3  ...                     70                         Lots
# a4  ...                     52                       Normal
#
#    chanceCreationPositioningClass  defencePressure defencePressureClass  \
# id
# a0                      Organised               50               Medium
# a1                      Organised               47               Medium
# a2                      Organised               47               Medium
# a3                      Organised               60               Medium
# a4                      Organised               47               Medium
#
#    defenceAggression  defenceAggressionClass defenceTeamWidth  \
# id
# a0                55                   Press               45
# a1                44                   Press               54
# a2                44                   Press               54
# a3                70                  Double               70
# a4                47                   Press               52
#
#     defenceTeamWidthClass defenceDefenderLineClass
# id
# a0                 Normal                    Cover
# a1                 Normal                    Cover
# a2                 Normal                    Cover
# a3                   Wide                    Cover
# a4                 Normal                    Cover
#
# [5 rows x 23 columns]

# %%
#1分别利用标签索引和位置索引，获取 id=a1457 的数据
print("利用标签索引获取 id=a1457：")
print(df.loc['a1457'])
# Out:
# 利用标签索引获取 id=a1457：
# team_api_id                                10000
# date                              2015/9/10 0:00
# buildUpPlaySpeed                              54
# buildUpPlaySpeedClass                   Balanced
# buildUpPlayDribbling                        42.0
# buildUpPlayDribblingClass                 Normal
# buildUpPlayPassing                            51
# buildUpPlayPassingClass                    Mixed
# buildUpPlayPositioningClass            Organised
# chanceCreationPassing                         47
# chanceCreationPassingClass                Normal
# chanceCreationCrossing                        52
# chanceCreationCrossingClass               Normal
# chanceCreationShooting                        32
# chanceCreationShootingClass               Little
# chanceCreationPositioningClass         Organised
# defencePressure                               44
# defencePressureClass                      Medium
# defenceAggression                             58
# defenceAggressionClass                     Press
# defenceTeamWidth                              37
# defenceTeamWidthClass                     Normal
# defenceDefenderLineClass                   Cover
# Name: a1457, dtype: object
# 利用位置索引获取 id=a1457（假设它在位置 i=？）：
#        team_api_id            date  buildUpPlaySpeed buildUpPlaySpeedClass  \
# id
# a1457        10000  2015/9/10 0:00                54              Balanced
#
#        buildUpPlayDribbling buildUpPlayDribblingClass  buildUpPlayPassing  \
# id
# a1457                  42.0                    Normal                  51
#
#       buildUpPlayPassingClass buildUpPlayPositioningClass  \
# id
# a1457                   Mixed                   Organised
#
#        chanceCreationPassing  ... chanceCreationShooting  \
# id                            ...
# a1457                     47  ...                     32
#
#        chanceCreationShootingClass chanceCreationPositioningClass  \
# id
# a1457                       Little                      Organised
#
#        defencePressure defencePressureClass defenceAggression  \
# id
# a1457               44               Medium                58
#
#        defenceAggressionClass defenceTeamWidth  defenceTeamWidthClass  \
# id
# a1457                   Press               37                 Normal
#
#       defenceDefenderLineClass
# id
# a1457                    Cover
#
# [1 rows x 23 columns]

# %%
print("利用位置索引获取 id=a1457（假设它在位置 i=？）：")
print(df.iloc[[df.index.get_loc('a1457')]])  # 先找位置，再取 iloc
# Out:
# 利用位置索引获取 id=a1457（假设它在位置 i=？）：
#        team_api_id            date  buildUpPlaySpeed buildUpPlaySpeedClass  \
# id
# a1457        10000  2015/9/10 0:00                54              Balanced
#
#        buildUpPlayDribbling buildUpPlayDribblingClass  buildUpPlayPassing  \
# id
# a1457                  42.0                    Normal                  51
#
#       buildUpPlayPassingClass buildUpPlayPositioningClass  \
# id
# a1457                   Mixed                   Organised
#
#        chanceCreationPassing  ... chanceCreationShooting  \
# id                            ...
# a1457                     47  ...                     32
#
#        chanceCreationShootingClass chanceCreationPositioningClass  \
# id
# a1457                       Little                      Organised
#
#        defencePressure defencePressureClass defenceAggression  \
# id
# a1457               44               Medium                58
#
#        defenceAggressionClass defenceTeamWidth  defenceTeamWidthClass  \
# id
# a1457                   Press               37                 Normal
#
#       defenceDefenderLineClass
# id
# a1457                    Cover
#
# [1 rows x 23 columns]

# %%
# 2获取 id 为 a0、a2、a4 的数据
print("获取 a0、a2、a4：")
print(df.loc[['a0', 'a2', 'a4']])
# Out:
# 获取 a0、a2、a4：
#     team_api_id            date  buildUpPlaySpeed buildUpPlaySpeedClass  \
# id
# a0         9930  2010/2/22 0:00                60              Balanced
# a2         9930  2015/9/10 0:00                47              Balanced
# a4         8485  2011/2/22 0:00                47              Balanced
#
#     buildUpPlayDribbling buildUpPlayDribblingClass  buildUpPlayPassing  \
# id
# a0                   NaN                    Little                  50
# a2                  41.0                    Normal                  54
# a4                   NaN                    Little                  52
#
#    buildUpPlayPassingClass buildUpPlayPositioningClass  chanceCreationPassing  \
# id
# a0                   Mixed                   Organised                     60
# a2                   Mixed                   Organised                     54
# a4                   Mixed                   Organised                     53
#
#     ... chanceCreationShooting  chanceCreationShootingClass  \
# id  ...
# a0  ...                     55                       Normal
# a2  ...                     64                       Normal
# a4  ...                     52                       Normal
#
#    chanceCreationPositioningClass  defencePressure defencePressureClass  \
# id
# a0                      Organised               50               Medium
# a2                      Organised               47               Medium
# a4                      Organised               47               Medium
#
#    defenceAggression  defenceAggressionClass defenceTeamWidth  \
# id
# a0                55                   Press               45
# a2                44                   Press               54
# a4                47                   Press               52
#
#     defenceTeamWidthClass defenceDefenderLineClass
# id
# a0                 Normal                    Cover
# a2                 Normal                    Cover
# a4                 Normal                    Cover
#
# [3 rows x 23 columns]

# %%
# 3获取位置为双数的行数据
print("位置为偶数的行：")
print(df.iloc[::2])
# Out:
# 位置为偶数的行：
#        team_api_id            date  buildUpPlaySpeed buildUpPlaySpeedClass  \
# id
# a0            9930  2010/2/22 0:00                60              Balanced
# a2            9930  2015/9/10 0:00                47              Balanced
# a4            8485  2011/2/22 0:00                47              Balanced
# a6            8485  2013/9/20 0:00                62              Balanced
# a8            8485  2015/9/10 0:00                59              Balanced
# ...            ...             ...               ...                   ...
# a1448         8394  2014/9/19 0:00                38              Balanced
# a1450         8027  2014/9/19 0:00                54              Balanced
# a1452        10000  2010/2/22 0:00                65              Balanced
# a1454        10000  2012/2/22 0:00                54              Balanced
# a1456        10000  2014/9/19 0:00                54              Balanced
#
#        buildUpPlayDribbling buildUpPlayDribblingClass  buildUpPlayPassing  \
# id
# a0                      NaN                    Little                  50
# a2                     41.0                    Normal                  54
# a4                      NaN                    Little                  52
# a6                      NaN                    Little                  45
# a8                     64.0                    Normal                  53
# ...                     ...                       ...                 ...
# a1448                  48.0                    Normal                  35
# a1450                  51.0                    Normal                  40
# a1452                   NaN                    Little                  60
# a1454                   NaN                    Little                  51
# a1456                  42.0                    Normal                  51
#
#       buildUpPlayPassingClass buildUpPlayPositioningClass  \
# id
# a0                      Mixed                   Organised
# a2                      Mixed                   Organised
# a4                      Mixed                   Organised
# a6                      Mixed                   Organised
# a8                      Mixed                   Organised
# ...                       ...                         ...
# a1448                   Mixed                   Organised
# a1450                   Mixed                   Organised
# a1452                   Mixed                   Organised
# a1454                   Mixed                   Organised
# a1456                   Mixed                   Organised
#
#        chanceCreationPassing  ... chanceCreationShooting  \
# id                            ...
# a0                        60  ...                     55
# a2                        54  ...                     64
# a4                        53  ...                     52
# a6                        40  ...                     55
# a8                        51  ...                     63
# ...                      ...  ...                    ...
# a1448                     53  ...                     57
# a1450                     67  ...                     52
# a1452                     60  ...                     50
# a1454                     47  ...                     50
# a1456                     47  ...                     32
#
#        chanceCreationShootingClass chanceCreationPositioningClass  \
# id
# a0                          Normal                      Organised
# a2                          Normal                      Organised
# a4                          Normal                      Organised
# a6                          Normal                      Organised
# a8                          Normal                      Free Form
# ...                            ...                            ...
# a1448                       Normal                      Organised
# a1450                       Normal                      Organised
# a1452                       Normal                      Organised
# a1454                       Normal                      Organised
# a1456                       Little                      Organised
#
#        defencePressure defencePressureClass defenceAggression  \
# id
# a0                  50               Medium                55
# a2                  47               Medium                44
# a4                  47               Medium                47
# a6                  42               Medium                42
# a8                  49               Medium                45
# ...                ...                  ...               ...
# a1448               51               Medium                46
# a1450               44               Medium                47
# a1452               70                 High                60
# a1454               44               Medium                55
# a1456               44               Medium                58
#
#        defenceAggressionClass defenceTeamWidth  defenceTeamWidthClass  \
# id
# a0                      Press               45                 Normal
# a2                      Press               54                 Normal
# a4                      Press               52                 Normal
# a6                      Press               60                 Normal
# a8                      Press               63                 Normal
# ...                       ...              ...                    ...
# a1448                   Press               61                 Normal
# a1450                   Press               52                 Normal
# a1452                   Press               70                   Wide
# a1454                   Press               53                 Normal
# a1456                   Press               37                 Normal
#
#       defenceDefenderLineClass
# id
# a0                       Cover
# a2                       Cover
# a4                       Cover
# a6                       Cover
# a8                       Cover
# ...                        ...
# a1448                    Cover
# a1450                    Cover
# a1452                    Cover
# a1454                    Cover
# a1456                    Cover
#
# [729 rows x 23 columns]

# %%
# 4获取 buildUpPlaySpeed 分数低于 30 的数据
print("buildUpPlaySpeed < 30：")
print(df[df['buildUpPlaySpeed'] < 30])
# Out:
# buildUpPlaySpeed < 30：
#        team_api_id            date  buildUpPlaySpeed buildUpPlaySpeedClass  \
# id
# a61         108893  2012/2/22 0:00                23                  Slow
# a72           9825  2012/2/22 0:00                25                  Slow
# a120          8634  2012/2/22 0:00                24                  Slow
# a504          8305  2012/2/22 0:00                25                  Slow
# a505          8305  2013/9/20 0:00                29                  Slow
# a628          9885  2014/9/19 0:00                26                  Slow
# a1035         8370  2015/9/10 0:00                29                  Slow
# a1056         8560  2012/2/22 0:00                24                  Slow
# a1057         8560  2013/9/20 0:00                28                  Slow
# a1256        10003  2012/2/22 0:00                26                  Slow
# a1294         8611  2012/2/22 0:00                25                  Slow
# a1309        10267  2012/2/22 0:00                20                  Slow
# a1310        10267  2013/9/20 0:00                20                  Slow
# a1337        10205  2012/2/22 0:00                20                  Slow
# a1338        10205  2013/9/20 0:00                24                  Slow
# a1410        10265  2012/2/22 0:00                25                  Slow
#
#        buildUpPlayDribbling buildUpPlayDribblingClass  buildUpPlayPassing  \
# id
# a61                     NaN                    Little                  33
# a72                     NaN                    Little                  32
# a120                    NaN                    Little                  25
# a504                    NaN                    Little                  40
# a505                    NaN                    Little                  40
# a628                   47.0                    Normal                  24
# a1035                  52.0                    Normal                  44
# a1056                   NaN                    Little                  36
# a1057                   NaN                    Little                  36
# a1256                   NaN                    Little                  24
# a1294                   NaN                    Little                  28
# a1309                   NaN                    Little                  35
# a1310                   NaN                    Little                  35
# a1337                   NaN                    Little                  26
# a1338                   NaN                    Little                  26
# a1410                   NaN                    Little                  25
#
#       buildUpPlayPassingClass buildUpPlayPositioningClass  \
# id
# a61                     Short                   Organised
# a72                     Short                   Organised
# a120                    Short                   Free Form
# a504                    Mixed                   Organised
# a505                    Mixed                   Organised
# a628                    Short                   Organised
# a1035                   Mixed                   Organised
# a1056                   Mixed                   Organised
# a1057                   Mixed                   Organised
# a1256                   Short                   Organised
# a1294                   Short                   Organised
# a1309                   Mixed                   Organised
# a1310                   Mixed                   Organised
# a1337                   Short                   Organised
# a1338                   Short                   Organised
# a1410                   Short                   Organised
#
#        chanceCreationPassing  ... chanceCreationShooting  \
# id                            ...
# a61                       49  ...                     43
# a72                       41  ...                     30
# a120                      37  ...                     54
# a504                      58  ...                     52
# a505                      58  ...                     52
# a628                      64  ...                     72
# a1035                     44  ...                     47
# a1056                     60  ...                     59
# a1057                     60  ...                     59
# a1256                     62  ...                     57
# a1294                     44  ...                     37
# a1309                     38  ...                     55
# a1310                     38  ...                     55
# a1337                     43  ...                     58
# a1338                     43  ...                     58
# a1410                     32  ...                     50
#
#        chanceCreationShootingClass chanceCreationPositioningClass  \
# id
# a61                         Normal                      Organised
# a72                         Little                      Free Form
# a120                        Normal                      Free Form
# a504                        Normal                      Organised
# a505                        Normal                      Organised
# a628                          Lots                      Organised
# a1035                       Normal                      Organised
# a1056                       Normal                      Organised
# a1057                       Normal                      Organised
# a1256                       Normal                      Free Form
# a1294                       Normal                      Organised
# a1309                       Normal                      Organised
# a1310                       Normal                      Organised
# a1337                       Normal                      Organised
# a1338                       Normal                      Organised
# a1410                       Normal                      Organised
#
#        defencePressure defencePressureClass defenceAggression  \
# id
# a61                 44               Medium                32
# a72                 57               Medium                57
# a120                66               Medium                63
# a504                49               Medium                45
# a505                49               Medium                45
# a628                23                 Deep                67
# a1035               54               Medium                52
# a1056               48               Medium                53
# a1057               48               Medium                53
# a1256               48               Medium                58
# a1294               62               Medium                68
# a1309               51               Medium                38
# a1310               51               Medium                38
# a1337               51               Medium                51
# a1338               51               Medium                51
# a1410               60               Medium                58
#
#        defenceAggressionClass defenceTeamWidth  defenceTeamWidthClass  \
# id
# a61                   Contain               36                 Normal
# a72                     Press               52                 Normal
# a120                    Press               66                 Normal
# a504                    Press               47                 Normal
# a505                    Press               47                 Normal
# a628                   Double               36                 Normal
# a1035                   Press               63                 Normal
# a1056                   Press               70                   Wide
# a1057                   Press               70                   Wide
# a1256                   Press               60                 Normal
# a1294                  Double               67                   Wide
# a1309                   Press               59                 Normal
# a1310                   Press               59                 Normal
# a1337                   Press               56                 Normal
# a1338                   Press               56                 Normal
# a1410                   Press               61                 Normal
#
#       defenceDefenderLineClass
# id
# a61                      Cover
# a72                      Cover
# a120                     Cover
# a504                     Cover
# a505                     Cover
# a628                     Cover
# a1035                    Cover
# a1056                    Cover
# a1057                    Cover
# a1256                    Cover
# a1294                    Cover
# a1309                    Cover
# a1310                    Cover
# a1337                    Cover
# a1338                    Cover
# a1410                    Cover
#
# [16 rows x 23 columns]

# %%
# 5利用索引和切片获取前5行数据（位置为0、2、4）
print("前5行中位置为 0、2、4 的数据：")
print(df.iloc[[0, 2, 4]])
# Out:
# 前5行中位置为 0、2、4 的数据：
#     team_api_id            date  buildUpPlaySpeed buildUpPlaySpeedClass  \
# id
# a0         9930  2010/2/22 0:00                60              Balanced
# a2         9930  2015/9/10 0:00                47              Balanced
# a4         8485  2011/2/22 0:00                47              Balanced
#
#     buildUpPlayDribbling buildUpPlayDribblingClass  buildUpPlayPassing  \
# id
# a0                   NaN                    Little                  50
# a2                  41.0                    Normal                  54
# a4                   NaN                    Little                  52
#
#    buildUpPlayPassingClass buildUpPlayPositioningClass  chanceCreationPassing  \
# id
# a0                   Mixed                   Organised                     60
# a2                   Mixed                   Organised                     54
# a4                   Mixed                   Organised                     53
#
#     ... chanceCreationShooting  chanceCreationShootingClass  \
# id  ...
# a0  ...                     55                       Normal
# a2  ...                     64                       Normal
# a4  ...                     52                       Normal
#
#    chanceCreationPositioningClass  defencePressure defencePressureClass  \
# id
# a0                      Organised               50               Medium
# a2                      Organised               47               Medium
# a4                      Organised               47               Medium
#
#    defenceAggression  defenceAggressionClass defenceTeamWidth  \
# id
# a0                55                   Press               45
# a2                44                   Press               54
# a4                47                   Press               52
#
#     defenceTeamWidthClass defenceDefenderLineClass
# id
# a0                 Normal                    Cover
# a2                 Normal                    Cover
# a4                 Normal                    Cover
#
# [3 rows x 23 columns]

# %%
# 6删除索引为 a0 的数据
df1 = df.drop(index='a0')
print(" 删除 a0 后：")
print(df1.head())
# Out:
#  删除 a0 后：
#     team_api_id            date  buildUpPlaySpeed buildUpPlaySpeedClass  \
# id
# a1         9930  2014/9/19 0:00                52              Balanced
# a2         9930  2015/9/10 0:00                47              Balanced
# a3         8485  2010/2/22 0:00                70                  Fast
# a4         8485  2011/2/22 0:00                47              Balanced
# a5         8485  2012/2/22 0:00                58              Balanced
#
#     buildUpPlayDribbling buildUpPlayDribblingClass  buildUpPlayPassing  \
# id
# a1                  48.0                    Normal                  56
# a2                  41.0                    Normal                  54
# a3                   NaN                    Little                  70
# a4                   NaN                    Little                  52
# a5                   NaN                    Little                  62
#
#    buildUpPlayPassingClass buildUpPlayPositioningClass  chanceCreationPassing  \
# id
# a1                   Mixed                   Organised                     54
# a2                   Mixed                   Organised                     54
# a3                    Long                   Organised                     70
# a4                   Mixed                   Organised                     53
# a5                   Mixed                   Organised                     45
#
#     ... chanceCreationShooting  chanceCreationShootingClass  \
# id  ...
# a1  ...                     64                       Normal
# a2  ...                     64                       Normal
# a3  ...                     70                         Lots
# a4  ...                     52                       Normal
# a5  ...                     55                       Normal
#
#    chanceCreationPositioningClass  defencePressure defencePressureClass  \
# id
# a1                      Organised               47               Medium
# a2                      Organised               47               Medium
# a3                      Organised               60               Medium
# a4                      Organised               47               Medium
# a5                      Organised               40               Medium
#
#    defenceAggression  defenceAggressionClass defenceTeamWidth  \
# id
# a1                44                   Press               54
# a2                44                   Press               54
# a3                70                  Double               70
# a4                47                   Press               52
# a5                40                   Press               60
#
#     defenceTeamWidthClass defenceDefenderLineClass
# id
# a1                 Normal                    Cover
# a2                 Normal                    Cover
# a3                   Wide                    Cover
# a4                 Normal                    Cover
# a5                 Normal                    Cover
#
# [5 rows x 23 columns]

# %%
# 7删除索引为 a0、a1 的数据
df2 = df.drop(index=['a0', 'a1'])
print("\n⑦ 删除 a0、a1 后：")
print(df2.head())
# Out:
# ⑦ 删除 a0、a1 后：
#     team_api_id            date  buildUpPlaySpeed buildUpPlaySpeedClass  \
# id
# a2         9930  2015/9/10 0:00                47              Balanced
# a3         8485  2010/2/22 0:00                70                  Fast
# a4         8485  2011/2/22 0:00                47              Balanced
# a5         8485  2012/2/22 0:00                58              Balanced
# a6         8485  2013/9/20 0:00                62              Balanced
#
#     buildUpPlayDribbling buildUpPlayDribblingClass  buildUpPlayPassing  \
# id
# a2                  41.0                    Normal                  54
# a3                   NaN                    Little                  70
# a4                   NaN                    Little                  52
# a5                   NaN                    Little                  62
# a6                   NaN                    Little                  45
#
#    buildUpPlayPassingClass buildUpPlayPositioningClass  chanceCreationPassing  \
# id
# a2                   Mixed                   Organised                     54
# a3                    Long                   Organised                     70
# a4                   Mixed                   Organised                     53
# a5                   Mixed                   Organised                     45
# a6                   Mixed                   Organised                     40
#
#     ... chanceCreationShooting  chanceCreationShootingClass  \
# id  ...
# a2  ...                     64                       Normal
# a3  ...                     70                         Lots
# a4  ...                     52                       Normal
# a5  ...                     55                       Normal
# a6  ...                     55                       Normal
#
#    chanceCreationPositioningClass  defencePressure defencePressureClass  \
# id
# a2                      Organised               47               Medium
# a3                      Organised               60               Medium
# a4                      Organised               47               Medium
# a5                      Organised               40               Medium
# a6                      Organised               42               Medium
#
#    defenceAggression  defenceAggressionClass defenceTeamWidth  \
# id
# a2                44                   Press               54
# a3                70                  Double               70
# a4                47                   Press               52
# a5                40                   Press               60
# a6                42                   Press               60
#
#     defenceTeamWidthClass defenceDefenderLineClass
# id
# a2                 Normal                    Cover
# a3                   Wide                    Cover
# a4                 Normal                    Cover
# a5                 Normal                    Cover
# a6                 Normal                    Cover
#
# [5 rows x 23 columns]

# %%
#8
df.loc['a3', 'buildUpPlaySpeed']          # 先行后列
df['buildUpPlaySpeed'].loc['a3']          # 先列后行
# Out:
# 70
# 70

# %%
df.loc[['a3','a5'], ['buildUpPlaySpeed','buildUpPlaySpeedClass']]
# 或
df[['buildUpPlaySpeed','buildUpPlaySpeedClass']].loc[['a3','a5']]
# Out:
#     buildUpPlaySpeed buildUpPlaySpeedClass
# id
# a3                70                  Fast
# a5                58              Balanced
#     buildUpPlaySpeed buildUpPlaySpeedClass
# id
# a3                70                  Fast
# a5                58              Balanced

# %%
df.loc['a3':'a5', ['buildUpPlaySpeed','buildUpPlaySpeedClass']]
# Out:
#     buildUpPlaySpeed buildUpPlaySpeedClass
# id
# a3                70                  Fast
# a4                47              Balanced
# a5                58              Balanced

# %%
df['buildUpPlayDribbling'].fillna(0, inplace=True)
df.head()
# Out:
#     team_api_id            date  buildUpPlaySpeed buildUpPlaySpeedClass  \
# id
# a0         9930  2010/2/22 0:00                60              Balanced
# a1         9930  2014/9/19 0:00                52              Balanced
# a2         9930  2015/9/10 0:00                47              Balanced
# a3         8485  2010/2/22 0:00                70                  Fast
# a4         8485  2011/2/22 0:00                47              Balanced
#
#     buildUpPlayDribbling buildUpPlayDribblingClass  buildUpPlayPassing  \
# id
# a0                   0.0                    Little                  50
# a1                  48.0                    Normal                  56
# a2                  41.0                    Normal                  54
# a3                   0.0                    Little                  70
# a4                   0.0                    Little                  52
#
#    buildUpPlayPassingClass buildUpPlayPositioningClass  chanceCreationPassing  \
# id
# a0                   Mixed                   Organised                     60
# a1                   Mixed                   Organised                     54
# a2                   Mixed                   Organised                     54
# a3                    Long                   Organised                     70
# a4                   Mixed                   Organised                     53
#
#     ... chanceCreationShooting  chanceCreationShootingClass  \
# id  ...
# a0  ...                     55                       Normal
# a1  ...                     64                       Normal
# a2  ...                     64                       Normal
# a3  ...                     70                         Lots
# a4  ...                     52                       Normal
#
#    chanceCreationPositioningClass  defencePressure defencePressureClass  \
# id
# a0                      Organised               50               Medium
# a1                      Organised               47               Medium
# a2                      Organised               47               Medium
# a3                      Organised               60               Medium
# a4                      Organised               47               Medium
#
#    defenceAggression  defenceAggressionClass defenceTeamWidth  \
# id
# a0                55                   Press               45
# a1                44                   Press               54
# a2                44                   Press               54
# a3                70                  Double               70
# a4                47                   Press               52
#
#     defenceTeamWidthClass defenceDefenderLineClass
# id
# a0                 Normal                    Cover
# a1                 Normal                    Cover
# a2                 Normal                    Cover
# a3                   Wide                    Cover
# a4                 Normal                    Cover
#
# [5 rows x 23 columns]

# %%
df.loc[df['buildUpPlaySpeed'] < 30, 'buildUpPlaySpeed'] = 30
df
# Out:
#        team_api_id            date  buildUpPlaySpeed buildUpPlaySpeedClass  \
# id
# a0            9930  2010/2/22 0:00                60              Balanced
# a1            9930  2014/9/19 0:00                52              Balanced
# a2            9930  2015/9/10 0:00                47              Balanced
# a3            8485  2010/2/22 0:00                70                  Fast
# a4            8485  2011/2/22 0:00                47              Balanced
# ...            ...             ...               ...                   ...
# a1453        10000  2011/2/22 0:00                52              Balanced
# a1454        10000  2012/2/22 0:00                54              Balanced
# a1455        10000  2013/9/20 0:00                54              Balanced
# a1456        10000  2014/9/19 0:00                54              Balanced
# a1457        10000  2015/9/10 0:00                54              Balanced
#
#        buildUpPlayDribbling buildUpPlayDribblingClass  buildUpPlayPassing  \
# id
# a0                      0.0                    Little                  50
# a1                     48.0                    Normal                  56
# a2                     41.0                    Normal                  54
# a3                      0.0                    Little                  70
# a4                      0.0                    Little                  52
# ...                     ...                       ...                 ...
# a1453                   0.0                    Little                  52
# a1454                   0.0                    Little                  51
# a1455                   0.0                    Little                  51
# a1456                  42.0                    Normal                  51
# a1457                  42.0                    Normal                  51
#
#       buildUpPlayPassingClass buildUpPlayPositioningClass  \
# id
# a0                      Mixed                   Organised
# a1                      Mixed                   Organised
# a2                      Mixed                   Organised
# a3                       Long                   Organised
# a4                      Mixed                   Organised
# ...                       ...                         ...
# a1453                   Mixed                   Organised
# a1454                   Mixed                   Organised
# a1455                   Mixed                   Organised
# a1456                   Mixed                   Organised
# a1457                   Mixed                   Organised
#
#        chanceCreationPassing  ... chanceCreationShooting  \
# id                            ...
# a0                        60  ...                     55
# a1                        54  ...                     64
# a2                        54  ...                     64
# a3                        70  ...                     70
# a4                        53  ...                     52
# ...                      ...  ...                    ...
# a1453                     52  ...                     53
# a1454                     47  ...                     50
# a1455                     47  ...                     32
# a1456                     47  ...                     32
# a1457                     47  ...                     32
#
#        chanceCreationShootingClass chanceCreationPositioningClass  \
# id
# a0                          Normal                      Organised
# a1                          Normal                      Organised
# a2                          Normal                      Organised
# a3                            Lots                      Organised
# a4                          Normal                      Organised
# ...                            ...                            ...
# a1453                       Normal                      Organised
# a1454                       Normal                      Organised
# a1455                       Little                      Organised
# a1456                       Little                      Organised
# a1457                       Little                      Organised
#
#        defencePressure defencePressureClass defenceAggression  \
# id
# a0                  50               Medium                55
# a1                  47               Medium                44
# a2                  47               Medium                44
# a3                  60               Medium                70
# a4                  47               Medium                47
# ...                ...                  ...               ...
# a1453               46               Medium                48
# a1454               44               Medium                55
# a1455               44               Medium                58
# a1456               44               Medium                58
# a1457               44               Medium                58
#
#        defenceAggressionClass defenceTeamWidth  defenceTeamWidthClass  \
# id
# a0                      Press               45                 Normal
# a1                      Press               54                 Normal
# a2                      Press               54                 Normal
# a3                     Double               70                   Wide
# a4                      Press               52                 Normal
# ...                       ...              ...                    ...
# a1453                   Press               53                 Normal
# a1454                   Press               53                 Normal
# a1455                   Press               37                 Normal
# a1456                   Press               37                 Normal
# a1457                   Press               37                 Normal
#
#       defenceDefenderLineClass
# id
# a0                       Cover
# a1                       Cover
# a2                       Cover
# a3                       Cover
# a4                       Cover
# ...                        ...
# a1453                    Cover
# a1454                    Cover
# a1455                    Cover
# a1456                    Cover
# a1457                    Cover
#
# [1458 rows x 23 columns]

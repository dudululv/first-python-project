# %%
#画常见函数图像
import numpy as np
import matplotlib.pyplot as plt
#生成从start到stop，num个元素的等差数列
x=np.linspace(0,3,100) 
print(x)
#创建画布与子图
fig,ax=plt.subplots(2,2)
ax[0,0].plot(x,np.exp(x)+8*x)
ax[0,1].plot(x,x**2-6*x+3)
ax[1,0].plot(x,8*x-2)
ax[1,1].plot(x,np.sin(x))
#若是觉得二维数组麻烦，可以使用ravel降维成一维数组，然后[0],[1],[2]……来索引
# ax=ax.ravel()
# ax[0].plot(x,np.exp(x)+8*x)
# ax[1].plot(x,x**2-6*x+3)
# ax[2].plot(x,8*x-2)
# ax[3].plot(x,np.sin(x))
# Out:
# [0.         0.03030303 0.06060606 0.09090909 0.12121212 0.15151515
#  0.18181818 0.21212121 0.24242424 0.27272727 0.3030303  0.33333333
#  0.36363636 0.39393939 0.42424242 0.45454545 0.48484848 0.51515152
#  0.54545455 0.57575758 0.60606061 0.63636364 0.66666667 0.6969697
#  0.72727273 0.75757576 0.78787879 0.81818182 0.84848485 0.87878788
#  0.90909091 0.93939394 0.96969697 1.         1.03030303 1.06060606
#  1.09090909 1.12121212 1.15151515 1.18181818 1.21212121 1.24242424
#  1.27272727 1.3030303  1.33333333 1.36363636 1.39393939 1.42424242
#  1.45454545 1.48484848 1.51515152 1.54545455 1.57575758 1.60606061
#  1.63636364 1.66666667 1.6969697  1.72727273 1.75757576 1.78787879
#  1.81818182 1.84848485 1.87878788 1.90909091 1.93939394 1.96969697
#  2.         2.03030303 2.06060606 2.09090909 2.12121212 2.15151515
#  2.18181818 2.21212121 2.24242424 2.27272727 2.3030303  2.33333333
#  2.36363636 2.39393939 2.42424242 2.45454545 2.48484848 2.51515152
#  2.54545455 2.57575758 2.60606061 2.63636364 2.66666667 2.6969697
#  2.72727273 2.75757576 2.78787879 2.81818182 2.84848485 2.87878788
#  2.90909091 2.93939394 2.96969697 3.        ]

# %%
#使用make_regression生成随机的数据集
from sklearn.datasets import make_regression
x,y,w=make_regression(n_samples=100,n_features=1,coef=True,
                      bias=0,noise=2.5,random_state=23)
print(w)
print(x)
print(y)#X（特征）永远是二维矩阵 → shape = (样本数, 特征数),y（标签）默认是一维向量 → shape = (样本数,)
#手动计算y
print(x.ravel()*w+2)
#画xy的散点图
plt.scatter(x,y, marker=".")
# Out:
# 62.72324997572558
# [[ 1.26724821]
#  [-0.02253889]
#  [ 0.51213739]
#  [ 0.81211867]
#  [ 0.66698806]
#  [ 0.41161964]
#  [-1.00994188]
#  [-0.54778801]
#  [-0.20184052]
#  [-0.76959905]
#  [ 0.42062266]
#  [-0.42084395]
#  [-0.36754812]
#  [-1.32214752]
#  [-1.0115352 ]
#  [ 0.43782968]
#  [ 1.12887685]
#  [-1.72325306]
#  [-0.04543758]
#  [ 0.70362363]
#  [-0.34745899]
#   -46.07473685   25.43795642    3.82695616  -32.85427676    9.07033972
#   -19.37017056  -51.41076194    3.93426284   39.58392905  -76.62768445
#    67.15632656   47.65545178   58.7136038   123.99196933   57.16821964
#   -48.89168633   74.72461898  132.86493262   -0.76446352 -160.78961332
#   -65.01116364   80.20572847   -5.18397234  108.53240062   -0.51132183
#    -2.18747357  -75.60007918   22.76768393   -6.47353693   75.346694  ]
# [  81.48592617    0.58628757   34.12292183   52.93872233   43.83565859
#    27.81812163  -61.34683679  -32.35904415  -10.66009354  -46.27175353
#    28.38282026  -24.39670048  -21.05381237  -80.92938956  -61.446775
#    29.46210049   72.80682507 -106.08803256   -0.84999241   46.13356084
#   -19.79375715  -42.4867098     8.25496809  -63.4485753    -6.54709382
#   -65.77653322   11.21783986  -63.92725168  101.92507611   29.67045626
#    -9.22969439  -49.27245124   17.72701143   65.41689562   30.7091202
#   -56.88261952   44.03336896  116.36820881   29.46603947  -32.62251674
#    40.83284675  -14.81874642   17.12297077   -2.47366836   -3.89816417
#   -40.61532209 -100.38857274   13.92628399   46.01113538   12.89086649
#    12.71424174    3.61908034   10.25052013   -4.34087608   44.45486632
#   -13.75263255  -57.74449342  123.24967689  -28.26769881   90.77346897
#    22.21391713   -8.12016975   30.93167627   67.28775108   85.28315499
#    60.70550553  -60.25745336   35.75526751 -113.28958407  201.93052781
#   -46.77481684   29.70714091    6.10248119  -33.37839856   14.05037066
#   -18.80010378  -49.03265527    5.78490494   40.02255128  -69.34516852
#    67.56908395   47.71746169   61.50139638  125.46662369   59.76785203
#   -47.887766     76.79147491  136.90390817    2.8418876  -155.19891067
#   -66.07773179   78.80027108    0.91131635  113.16179901    2.64161503
#    -6.34373468  -74.72651499   28.66616775   -5.59563177   80.06601427]

# %%
#尝试自己洗牌
a = np. arange (10)#生成array range，起始值默认为0，终止值自设，步长默认为1
b = a * 20
np. random. seed (30)
np. random. shuffle (a)
np. random. seed (30)#若去掉该步，则ab各自洗牌，结果不一一对应
np. random. shuffle (b)
print (a)
print (b)
# Out:
# [0 1 2 3 6 4 7 8 9 5]
# [  0  20  40  60 120  80 140 160 180 100]

# %%
#通过索引来实现洗牌后顺序依旧对应
a = np. arange (10)
b = a * 20
index=np.arange(a.shape[0])
np.random.shuffle(index)
print(index)
print(a[index])
print(b[index])
# Out:
# [5 0 4 2 8 6 7 9 3 1]
# [5 0 4 2 8 6 7 9 3 1]
# [100   0  80  40 160 120 140 180  60  20]

# %%
#使用train_test_split切分数据集
#切分时，需多个数组的第一维长度（样本数量）相同
from sklearn.model_selection import train_test_split
#test和train_size直写一个就行：整数参数时，表示绝对的样本数量；浮点数时，表示比例
x_train,x_test,y_train,y_test=train_test_split(x.ravel(),y,
                                               test_size=0.3,
shuffle=True,random_state=3)#前面用make_regression生成的x是2维的，需要ravel一下
#即使种子固定，shuffle也会运行一次，也就是说，数据会和传入时顺序不同
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# print(x_train)
# print(x_test)
# print(y_train)
# print(y_test)
# Out:
# (70,) (30,) (70,) (30,)

# %%
#参数求解
a=np.sum((x_train-x_train.mean())*(y_train-y_train.mean()))#该步运算逻辑如下
#步骤 1：计算x_train的均值（x_train.mean()）
#步骤 2：计算x_train的离均差（x_train - x_train.mean()）
#步骤 3：计算y_train的均值和离均差（y_train - y_train.mean()）
#步骤 4：对应元素相乘（(x_train - x_train.mean()) * (y_train - y_train.mean())）
#步骤 5：求和（np.sum(...)）
# 可以写成a=(x_train-x_train.mean())@(y_train-y_train.mean())，即直接点积
b=np.sum((x_train-x_train.mean())**2)
w1=a/b
w0=y_train.mean()-w1*x_train.mean()
print(w1)
print(w0)
# Out:
# 63.05928549516441
# -0.06343530455385427

# %%
#点积
c=x_train-x_train.mean()
d=y_train-y_train.mean()
a=np.dot(c,d)
b=np.dot(c,c)
w1=a/b
w0=y_train.mean()-w1*x_train.mean()
print(w1)
print(w0)
# Out:
# 63.059285495164424
# -0.06343530455385604

# %%
#实现预测
y_hat=w1*x_test+w0
print(y_hat)
print(y_test)
# Out:
# [ 111.69390544   33.87267374  -63.74964843   83.66590349  -77.20100734
#   124.06465237   -7.69976015   15.14055574  -68.20307666   27.54579151
#     3.74174701  -48.59380145   27.79214472   26.74559462   28.79949204
#   -20.97497422   59.75673574  -65.86264686   89.18563145  -42.90706607
#   -35.63137121  -23.24075689  -12.79135443   41.99635496  -71.79083068
#    75.12872981 -108.73054211   58.95658096   11.92674294   10.70820726]
# [ 108.53240062   37.22153626  -61.99710727   78.99716334  -75.60007918
#   123.99196933   -6.47353693   16.19548345  -67.4552734    25.48643074
#     3.93426284  -50.92533875   25.43795642   22.76768393   31.30547656
#   -19.37017056   58.7136038   -65.25833529   87.80560138  -46.16964765
#   -32.85427676  -23.58186256   -8.92363      37.86054725  -76.62768445
#    74.72461898 -108.52848381   60.17089218   15.11490031    5.3445318 ]

# %%
# plt.rcParams["font.family"] = "SimHei"
# plt.rcParams["axes.unicode_minus"] = False

plt.scatter(train_x, train_y, c="g", marker=".", label="训练集")
plt.scatter(test_x, test_y, c="orange", marker="*", label="测试集")
t = np.linspace(train_x.min() - 0.5, train_x.max() + 0.5, 100)
t2 = w0 + w1 * t
plt.plot(t, t2, c="r", label="回归线")
plt.legend()
plt.xlabel("x")
plt.ylabel("y")
plt.title(f"回归方程：y={w0:.2f} + {w1:.2f} * x")

plt.figure(figsize=(12, 5))
index = np.arange(test_y.shape[0])
plt.plot(index,test_y, label="真实值", color="r", marker="o", ls="--")
plt.plot(index, y_hat, label="预测值", color="g", marker="o", ls="--")
plt.xlabel("测试集样本序号")
plt.ylabel("样本的真实值（预测值）")
plt.legend()

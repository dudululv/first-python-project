# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = "SimHei"
plt.rcParams["axes.unicode_minus"] = False

def fun(x):
    """定义目标函数。
    """
    return x ** 2 - 2 * x + 1

def grad_f(x):
    """目标函数的梯度函数，返回目标函数在点x处的梯度值。
    """
    return 2 * x - 2

def grad_descent(f, g, x_init, eta=0.1, tol=1e-4, max_iter=100, verbose=True):
    """执行梯度下降，求解目标函数的最小值。
    
    Parameters
    ----------
    f : function
        目标函数。
    g : function
        目标函数的梯度函数。
    x_init : float
        初始点的位置。
    eta : float
        学习率。
    tol : float
        容忍度。在梯度法执行过程中，如果y的下降幅度，比tol还要小，则停止迭代。
    max_iter : int
        最大迭代次数。
    verbose : bool
        是否显示更加详尽的信息。
    """
    # 定义列表，用来存储梯度法执行过程中，x与y的更新轨迹。
    x_list = []
    y_list = []
    x = x_init
    for i in range(max_iter):
        x_list.append(x)
        y = f(x)
        y_list.append(y)
        # 如果当前的y，比上一次迭代的y值，下降幅度小于tol，则停止迭代。
        if len(y_list) >= 2 and y_list[-2] - y < tol:
            break
        # 根据负梯度的方向，更新自变量，使得函数值越来越小。
        x = x - eta * g(x)
    if verbose:
        for index, (a, b) in enumerate(zip(x_list, y_list), start=1):
            print(f"第{index}次迭代 x={a} y={b}")
    return x_list, y_list


x_list, y_list = grad_descent(fun, grad_f, x_init=10)
# Out:
# 第1次迭代 x=10 y=81
# 第2次迭代 x=8.2 y=51.839999999999996
# 第3次迭代 x=6.76 y=33.1776
# 第4次迭代 x=5.608 y=21.233663999999997
# 第5次迭代 x=4.6864 y=13.58954496
# 第6次迭代 x=3.9491199999999997 y=8.697308774399998
# 第7次迭代 x=3.3592959999999996 y=5.5662776156159985
# 第8次迭代 x=2.8874367999999997 y=3.562417673994238
# 第9次迭代 x=2.5099494399999998 y=2.279947311356313
# 第10次迭代 x=2.2079595519999997 y=1.4591662792680404
# 第11次迭代 x=1.9663676415999998 y=0.9338664187315455
# 第12次迭代 x=1.7730941132799998 y=0.5976745079881893
# 第13次迭代 x=1.6184752906239999 y=0.38251168511244105
# 第14次迭代 x=1.4947802324992 y=0.24480747847196227
# 第15次迭代 x=1.3958241859993599 y=0.15667678622205594
# 第16次迭代 x=1.316659348799488 y=0.10027314318211578
# 第17次迭代 x=1.2533274790395903 y=0.06417481163655414
# 第18次迭代 x=1.2026619832316723 y=0.041071879447394544
# 第19次迭代 x=1.1621295865853378 y=0.026286002846332535
# 第20次迭代 x=1.1297036692682703 y=0.01682304182165284
# 第21次迭代 x=1.1037629354146161 y=0.01076674676585787
# 第22次迭代 x=1.0830103483316929 y=0.0068907179301489485
# 第23次迭代 x=1.0664082786653544 y=0.00441005947529538
# 第24次迭代 x=1.0531266229322835 y=0.0028224380641890257
# 第25次迭代 x=1.0425012983458268 y=0.0018063603610809498
# 第26次迭代 x=1.0340010386766614 y=0.001156070631091799
# 第27次迭代 x=1.0272008309413292 y=0.0007398852038986714
# 第28次迭代 x=1.0217606647530633 y=0.0004735265304951497
# 第29次迭代 x=1.0174085318024506 y=0.00030305697951682475
# 第30次迭代 x=1.0139268254419604 y=0.00019395646689090995
# 第31次迭代 x=1.0111414603535684 y=0.00012413213881012908

# %%
def plot_result(f, x, x_li, y_li):
    """绘制梯度法更新，自变量与函数的更新轨迹。
    
    Parameters
    ----------
    f : function
        目标函数。
    x : array
        目标函数f的定义域。
    x_li : list
        自变量的更新轨迹。
    y_li : list
        函数值的更新轨迹。
    """
    y = f(x)
    plt.plot(x, y, c="y")
    plt.plot(x_li, y_li, marker="o", ls="--", c="r")
    plt.plot(x_li[0], y_li[0], marker="*", ms=15, c="b", label="起始点")
    plt.plot(x_li[-1], y_li[-1], marker="*", ms=15, c="g", label="终止点")
    plt.legend()
    
domain = np.linspace(-9, 11, 200)
plot_result(fun, domain, x_list, y_list)


x_list, y_list = grad_descent(fun, grad_f, x_init=10, eta=0.3)
plot_result(fun, domain, x_list, y_list)

x_list, y_list = grad_descent(fun, grad_f, x_init=10, eta=0.7)
plot_result(fun, domain, x_list, y_list)

x_list, y_list = grad_descent(fun, grad_f, x_init=10, eta=1.5)
plot_result(fun, domain, x_list, y_list)

x_list, y_list = grad_descent(fun, grad_f, x_init=10, eta=0.005, verbose=False)
plot_result(fun, domain, x_list, y_list)
# Out:
# 第1次迭代 x=10 y=81
# 第2次迭代 x=4.6000000000000005 y=12.960000000000003
# 第3次迭代 x=2.4400000000000004 y=2.0736000000000008
# 第4次迭代 x=1.576 y=0.33177600000000007
# 第5次迭代 x=1.2304 y=0.05308416000000005
# 第6次迭代 x=1.09216 y=0.008493465599999972
# 第7次迭代 x=1.036864 y=0.0013589544959999866
# 第8次迭代 x=1.0147456 y=0.0002174327193600334
# 第9次迭代 x=1.00589824 y=3.478923509758758e-05
# 第10次迭代 x=1.002359296 y=5.566277615720594e-06
# 第1次迭代 x=10 y=81
# 第2次迭代 x=-2.5999999999999996 y=12.959999999999997
# 第3次迭代 x=2.4399999999999995 y=2.073599999999999
# 第4次迭代 x=0.4240000000000004 y=0.3317759999999996
# 第5次迭代 x=1.2304 y=0.05308416000000005
# 第6次迭代 x=0.90784 y=0.008493465599999972
# 第7次迭代 x=1.036864 y=0.0013589544959999866
# 第8次迭代 x=0.9852544 y=0.0002174327193600334
# 第9次迭代 x=1.00589824 y=3.478923509758758e-05
# 第10次迭代 x=0.9976407039999999 y=5.566277615609572e-06
# 第1次迭代 x=10 y=81
# 第2次迭代 x=-17.0 y=324.0

# %%
def fun(x1, x2):
    """目标函数。
    """
    return 0.2 * (x1 + x2) ** 2 - 0.3 * x1 * x2 + 0.4

def grad_f_x1(x1, x2):
    """目标函数在(x1, x2)点，对x1求梯度（偏导）。
    """
    return 0.4 * (x1 + x2) - 0.3 * x2

def grad_f_x2(x1, x2):
    """目标函数在(x1, x2)点，对x2求梯度（偏导）。
    """
    return 0.4 * (x1 + x2) - 0.3 * x1

def grad_descent(f, g, x_init, eta=0.1, tol=1e-4, max_iter=100, verbose=True):
    x_list = []
    y_list = []
    x1, x2 = x_init
    g1, g2 = g
    for i in range(max_iter):
        x_list.append((x1, x2))
        y = f(x1, x2)
        y_list.append(y)
        if len(y_list) >= 2 and y_list[-2] - y < tol:
            break
        v1 = g1(x1, x2)
        v2 = g2(x1, x2)
        x1 -= eta * v1
        x2 -= eta * v2
    if verbose:
        for index, (a, b) in enumerate(zip(x_list, y_list), start=1):
            print(f"第{index}次迭代， x={a} y={b}")
    return x_list, y_list

x_list, y_list = grad_descent(fun, g=(grad_f_x1, grad_f_x2), x_init=(4.8, 4.5), eta=0.4)
# Out:
# 第1次迭代， x=(4.8, 4.5) y=11.218000000000002
# 第2次迭代， x=(3.8519999999999994, 3.5879999999999996) y=7.3244272000000015
# 第3次迭代， x=(3.0921599999999994, 2.8598399999999993) y=4.832335943679999
# 第4次迭代， x=(2.4830207999999994, 2.2785791999999994) y=3.2372390475857906
# 第5次迭代， x=(1.9945943039999994, 1.8146856959999993) y=2.216254297842436
# 第6次迭代， x=(1.6028717875199994, 1.4445522124799994) y=1.5627290110600622
# 第7次迭代， x=(1.2886302130175995, 1.1493089869823996) y=1.1443992231638758
# 第8次迭代， x=(1.0364770194554875, 0.9138743405445117) y=0.8766111596974417
# 第9次迭代， x=(0.834085722720829, 0.7261953652791703) y=0.7051826588884744
# 第10次迭代， x=(0.6715841924743295, 0.5766406779256699) y=0.5954342362072508
# 第11次迭代， x=(0.54106509456141, 0.4575148017585895) y=0.5251687750238654
# 第12次迭代， x=(0.4361940873612409, 0.36266982969475875) y=0.48017838098166243
# 第13次迭代， x=(0.35189624019565197, 0.2871948934491477) y=0.45136865445823526
# 第14次迭代， x=(0.2841050460263817, 0.227167860889458) y=0.43291813639712035
# 第15次迭代， x=(0.2295615242265823, 0.17945680130608943) y=0.4211002850721143
# 第16次迭代， x=(0.18565340829808555, 0.14156125212805182) y=0.41352948811740325
# 第17次迭代， x=(0.15028641288526978, 0.11148531545564011) y=0.4086784691069542
# 第18次迭代， x=(0.12178117420540101, 0.08763620846732689) y=0.4055693959220811
# 第19次迭代， x=(0.09879073799384376, 0.06874316814433855) y=0.40357616544727926
# 第20次迭代， x=(0.0802344931890552, 0.053792631721490625) y=0.4022978466793136
# 第21次迭代， x=(0.06524526900994675, 0.04197643091848992) y=0.40147766952890246
# 第22次迭代， x=(0.05312696873161567, 0.03265039121113366) y=0.40095116620186494
# 第23次迭代， x=(0.043320638086111814, 0.025301249868087648) y=0.4006129728146812
# 第24次迭代， x=(0.03537728599761042, 0.01952022436574915) y=0.40039557556078165
# 第25次迭代， x=(0.028936111263362787, 0.014981897027324867) y=0.40025570293864854
# 第26次迭代， x=(0.023707057580131745, 0.011427349052418377) y=0.4001656126592921

# %%
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib qt

def plot_result(f, x, x_li, y_li):
    x1, x2 = x
    X1, X2 = np.meshgrid(x1, x2)
    X = np.array([X1.ravel(), X2.ravel()]).T
    y = f(X[:, 0], X[:, 1])
    Y = y.reshape(X1.shape)
    fig = plt.figure()
    ax = Axes3D(fig)
    fig.add_axes(ax)
    surf = ax.plot_surface(X1, X2, Y, rstride=5, cstride=5, cmap=plt.cm.rainbow, alpha=0.7)
    # x_li 是一个二维列表，不方便取列，为了方便取列，我们将其转换为ndarray数组。
    array = np.asarray(x_li)
    x1_trace = array[:, 0]
    x2_trace = array[:, 1]
    ax.plot(x1_trace, x2_trace, y_li, c="b", ls="--", marker="o")
    ax.plot(x1_trace[0], x2_trace[0], y_li[0], marker="*", ms=15, label="起始点", c="b")
    ax.plot(x1_trace[-1], x2_trace[-1], y_li[-1], marker="*", ms=15, label="终止点", c="g")
    fig.colorbar(surf)
    ax.legend()
    
    fig2 = plt.figure()
    ax2 = fig2.gca()
    # 绘制填充的等高线。
    # levels：设置登高线的疏密程度，该值越大，则等高线越密。
    m = ax2.contourf(X1, X2, Y, levels=30)
    ax2.scatter(x1_trace, x2_trace, c="r")
    fig2.colorbar(m)
    
x1_domain = np.linspace(-5, 5, 100)
x2_domain = np.linspace(-5, 5, 100)
plot_result(fun, (x1_domain, x2_domain), x_list, y_list)

# %%
import pandas as pd
import numpy as np
#实现重复值处理
# 实现player_attributes重复值的发现与处理
# 加载player_attributes_forduplicate数据集，该数据是专为重复值处理设置的数据集
df = pd.read_excel('../data/player_attributes_for duplicate.xlsx')
df
#实现发现重复数据居（假定认为所有数据重复则为重复数据）
df.duplicated().sum()
# 实现发现重复数据(假定认为player_api_id和date相同的即为重复数据)
df.duplicated(subset=['player_api_id','date'])
#删除重复数据
df.drop_duplicates(subset=['player_api_id','date'])
# Out:
#     Unnamed: 0  player_api_id       date  overall_rating  potential  \
# 0            0         505942 2016-02-18              67         71
# 1            1         505942 2015-11-19              67         71
# 2            2         505942 2015-09-21              62         66
# 3            3         505942 2015-03-20             161         65
# 4            4         505942 2007-02-22              61         65
# 5            5         155782 2016-04-21              74         76
# 6            7         155782 2016-01-07              73         75
# 7            7         155782 2016-01-07              73         75
# 8            8         155782 2015-12-24              73         75
# 9            9         155782 2015-12-17              73         75
# 10          10         155782 2015-10-16              73         77
# 11          11         155782 2015-09-25              74         78
# 12          12         155782 2015-09-21              73         77
# ...

# %%
import pandas as pd
import numpy as np

# %%
#缺失值的判断
s = pd.Series([np.nan,None,''])
s
s.isna()
s.isnull()
s[s.isnull()]
S==''
s[s=='']
# Out:
# 0     NaN
# 1    None
# 2
# dtype: object
# 0     True
# 1     True
# 2    False
# dtype: bool
# 0     True
# 1     True
# 2    False
# dtype: bool
# 0     NaN
# 1    None
# dtype: object
# 0    False
# 1    False
# 2     True
# dtype: bool
# 2
# dtype: object

# %%
#
df=pd.DataFrame({
'age':[18,19,21,121,np.nan,19,5,5,-3],
'gender':['F','M','F','X','F',np.nan,'F','F','M'],
'score':[78,-89,93,np.nan,64,np.nan,23,23,79]
})

df.isnull().any()
df.isnull().sum()
# Out:
# age       True
# gender    True
# score     True
# dtype: bool
# age       1
# gender    1
# score     2
# dtype: int64

# %%
#利用isnuLL（）、any（）以及sum（）实现球员评价数据表
#空值统计
df=pd.read_csv('../data/player_attributes.csv')
df.head(2)
#实现overallrating列的空值判断
df.info()
# Out:
#    id  player_api_id             date  overall_rating  potential  \
# 0   0         505942   2016/2/18 0:00            67.0       71.0
# 1   1         505942  2015/11/19 0:00            67.0       71.0
#
#   preferred_foot attacking_work_rate defensive_work_rate  crossing  finishing  \
# 0          right              medium              medium      49.0       44.0
# 1          right              medium              medium      49.0       44.0
#
#    ...  vision  penalties  marking  standing_tackle  sliding_tackle  \
# 0  ...    54.0       48.0     65.0             69.0            69.0
# 1  ...    54.0       48.0     65.0             69.0            69.0
#
#    gk_diving  gk_handling  gk_kicking  gk_positioning  gk_reflexes
# 0        6.0         11.0        10.0             8.0          8.0
# 1        6.0         11.0        10.0             8.0          8.0
#
# [2 rows x 41 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183978 entries, 0 to 183977
# ...

# %%
#实现整个数据表的空值判断
df.isnull()
df.isnull().any()
df.isnull().sum()
# Out:
#            id  player_api_id   date  overall_rating  potential  \
# 0       False          False  False           False      False
# 1       False          False  False           False      False
# 2       False          False  False           False      False
# 3       False          False  False           False      False
# 4       False          False  False           False      False
# ...       ...            ...    ...             ...        ...
# 183973  False          False  False           False      False
# 183974  False          False  False           False      False
# 183975  False          False  False           False      False
# 183976  False          False  False           False      False
# 183977  False          False  False           False      False
#
#         preferred_foot  attacking_work_rate  defensive_work_rate  crossing  \
# 0                False                False                False     False
# ...

# %%
df.overall_rating.isnull() .any()
df.overall_rating.isnull().sum()
# Out:
# True
# 836

# %%
import torch

print("torch version:", torch.__version__)
print("cuda available:", torch.cuda.is_available())
print("cuda runtime:", torch.version.cuda)
print("gpu:", torch.cuda.get_device_name(0))
# Out:
# torch version: 2.9.1+cu126
# cuda available: True
# cuda runtime: 12.6
# gpu: NVIDIA GeForce RTX 5060 Laptop GPU
# c:\ai\anaconda3\envs\ai\Lib\site-packages\torch\cuda\__init__.py:283: UserWarning:
#     Found GPU0 NVIDIA GeForce RTX 5060 Laptop GPU which is of cuda capability 12.0.
#     Minimum and Maximum cuda capability supported by this version of PyTorch is
#     (5.0) - (9.0)
#
#   warnings.warn(
# c:\ai\anaconda3\envs\ai\Lib\site-packages\torch\cuda\__init__.py:304: UserWarning:
#     Please install PyTorch with a following CUDA
#     configurations:  12.8 13.0 following instructions at
#     https://pytorch.org/get-started/locally/
#
#   warnings.warn(matched_cuda_warn.format(matched_arches))
# c:\ai\anaconda3\envs\ai\Lib\site-packages\torch\cuda\__init__.py:326: UserWarning:
# NVIDIA GeForce RTX 5060 Laptop GPU with CUDA capability sm_120 is not compatible with the current PyTorch installation.
# The current PyTorch install supports CUDA capabilities sm_50 sm_60 sm_61 sm_70 sm_75 sm_80 sm_86 sm_90.
# If you want to use the NVIDIA GeForce RTX 5060 Laptop GPU GPU with PyTorch, please check the instructions at https://pytorch.org/get-started/locally/
#
#   warnings.warn(

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#折线图
df= pd.read_csv('../data/折线图数据.csv')
#没有索弓# df #没有索引时,画折线图,需要指定x轴为月份,y轴不指定是所有列
df
# Out:
# Duplicate key in file WindowsPath('c:/ai/anaconda3/envs/ai/Lib/site-packages/matplotlib/mpl-data/matplotlibrc'), line 801 ('font.sans-serif : SimHei        # 设置默认中文字体为黑体')
# Duplicate key in file WindowsPath('c:/ai/anaconda3/envs/ai/Lib/site-packages/matplotlib/mpl-data/matplotlibrc'), line 802 ('axes.unicode_minus : False      # 解决负号显示为方块的问题')
#      月份  苹果  橙子
# 0    1月  11  13
# 1    2月  14  12
# 2    3月  13  14
# 3    4月  15  15
# 4    5月  16  14
# 5    6月  14  17
# 6    7月  16  15
# 7    8月  18  19
# 8    9月  20  21
# 9   10月  19  22
# 10  11月  17  20
# 11  12月  18  21

# %%
df.plot(x='月份',y='苹果')
# Out:
# <Axes: xlabel='月份'>

# %%
df.plot.line(x='月份',y='苹果')
# Out:
# <Axes: xlabel='月份'>

# %%
df.plot(kind='bar',x='月份',y='苹果')
# Out:
# <Axes: xlabel='月份'>

# %%
df_fruit= pd.read_csv('../data/折线图数据.csv',index_col=0)#有索引
df_fruit
# Out:
#      苹果  橙子
# 月份
# 1月   11  13
# 2月   14  12
# 3月   13  14
# 4月   15  15
# 5月   16  14
# 6月   14  17
# 7月   16  15
# 8月   18  19
# 9月   20  21
# 10月  19  22
# 11月  17  20
# 12月  18  21

# %%
df_fruit.plot(y='苹果')
# Out:
# <Axes: xlabel='月份'>

# %%
df.plot()
# Out:
# <Axes: >

# %%
import matplotlib
print(matplotlib.matplotlib_fname())
# Out:
# c:\ai\anaconda3\envs\ai\Lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %%
#多分类折线图
df.plot(x='月份')
df_fruit.plot(title='苹果和橙子的每月销量对比图')
# Out:
# <Axes: xlabel='月份'>
# <Axes: title={'center': '苹果和橙子的每月销量对比图'}, xlabel='月份'>

# %%
#折线图在足球数据集中的应用
df=pd.read_csv('../data/player.csv')
df.head(2)
# 足球运动员的身高分布
df.height.value_counts().sort_index().plot()
#梅西(30981)评分与潜能随时间的变化趋势
df=pd.read_csv('../data/player_attributes.csv')
df.head(2)
df.date=pd.to_datetime(df.date)
meixi=df.loc[df.player_api_id==30981,['date','overall_rating','potential']]
meixi.plot(x='date',rot=0,figsize=(16,6))
# Out:
#    player_api_id         player_name             birthday  height  weight
# 0         505942  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 1         155782     Aaron Cresswell  1989-12-15 00:00:00  170.18     146
# <Axes: xlabel='height'>
#    id  player_api_id             date  overall_rating  potential  \
# 0   0         505942   2016/2/18 0:00            67.0       71.0
# 1   1         505942  2015/11/19 0:00            67.0       71.0
#
#   preferred_foot attacking_work_rate defensive_work_rate  crossing  finishing  \
# 0          right              medium              medium      49.0       44.0
# 1          right              medium              medium      49.0       44.0
#
#    ...  vision  penalties  marking  standing_tackle  sliding_tackle  \
# 0  ...    54.0       48.0     65.0             69.0            69.0
# 1  ...    54.0       48.0     65.0             69.0            69.0
#
#    gk_diving  gk_handling  gk_kicking  gk_positioning  gk_reflexes
# ...

# %%
#图例的调整
team_ids=[ int(i)for i in'''
6269
7943
8524
8529
8533
8534
8535'''.strip().split('\n')]
team_ids
#导入 数据
df=pd.read_csv('../data/match_goal.csv')
df.head(2)
team=df.query('team_api_id.isin(@team_ids)').groupby(['season','team_api_id']).team_goal.sum().unstack()
team.plot(figsize=(16,6))
from matplotlib import pyplot as plt
plt.legend(bbox_to_anchor=(1,1))
# Out:
# [6269, 7943, 8524, 8529, 8533, 8534, 8535]
#    id  league_id     season  stage  match_api_id local  team_api_id  team_goal
# 0   0          1  2008/2009     24        493017  away         9987          1
# 1   1          1  2008/2009     24        493017  home         8203          2
# <Axes: xlabel='season'>

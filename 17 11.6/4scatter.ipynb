# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('../data/散点图数据.csv')
df
df.plot.scatter(x='身高',y='体重',c='red',s=1,marker='>')
# Out:
#       序号 性别     身高    体重
# 0      1  女  161.2  51.6
# 1      2  女  170.0  59.0
# 2      3  女  172.5  55.2
# 3      4  女  147.2  49.8
# 4      5  女  159.5  50.6
# ..   ... ..    ...   ...
# 502  503  男  188.0  94.3
# 503  504  男  188.0  87.3
# 504  505  男  188.0  85.9
# 505  506  男  179.1  89.1
# 506  507  男  177.8  84.1
#
# [507 rows x 4 columns]
# <Axes: xlabel='身高', ylabel='体重'>

# %%
fig,a=plt.subplots()
df.query('性别==\'女\'').plot.scatter(x='身高',y='体重',c='r',s=1,marker='>')
# Out:
# <Axes: xlabel='身高', ylabel='体重'>

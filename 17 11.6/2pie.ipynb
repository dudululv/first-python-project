# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('../data/饼图数据.csv')
df
df['quarter']=['no.1']*3+['no.2']*3+['no.3']*3+['no.4']*3
df
df.groupby('quarter').苹果.sum().sort_index().plot.pie(autopct='%.2f%%',pctdistance=0.5\
    ,labeldistance=1)
plt.legend(bbox_to_anchor=(1,1))
# Out:
#      月份  苹果
# 0    1月  11
# 1    2月  14
# 2    3月  13
# 3    4月  15
# 4    5月  16
# 5    6月  14
# 6    7月  16
# 7    8月  18
# 8    9月  20
# 9   10月  19
# 10  11月  17
# 11  12月  18
#      月份  苹果 quarter
# 0    1月  11    no.1
# 1    2月  14    no.1
# 2    3月  13    no.1
# 3    4月  15    no.2
# 4    5月  16    no.2
# 5    6月  14    no.2
# 6    7月  16    no.3
# 7    8月  18    no.3
# 8    9月  20    no.3
# 9   10月  19    no.4
# 10  11月  17    no.4
# 11  12月  18    no.4
# <Axes: ylabel='苹果'>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('../data/match_goal.csv')
df
df.query('team_api_id==8535').groupby(['season','local']).team_goal.sum().unstack()\
    .rename(columns={'away':'away_team_goal','home':'home_team_goal'})\
    .plot.area(stacked=False)
# Out:
#           id  league_id     season  stage  match_api_id local  team_api_id  \
# 0          0          1  2008/2009     24        493017  away         9987
# 1          1          1  2008/2009     24        493017  home         8203
# 2          2          1  2008/2009     25        493025  away         8342
# 3          3          1  2008/2009     25        493025  home         9984
# 4          4          1  2008/2009     25        493027  away        10000
# ...      ...        ...        ...    ...           ...   ...          ...
# 42717  42717      24558  2015/2016     36       1992227  home        10199
# 42718  42718      24558  2015/2016     36       1992228  away        10192
# 42719  42719      24558  2015/2016     36       1992228  home        10191
# 42720  42720      24558  2015/2016     36       1992229  away         9824
# 42721  42721      24558  2015/2016     36       1992229  home        10243
#
#        team_goal
# 0              1
# 1              2
# ...

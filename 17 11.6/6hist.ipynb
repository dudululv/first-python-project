# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(0)
df=pd.DataFrame(np.random.uniform(-5,5,(100,3)),columns=['a','b','c'])
df
df.plot.kde()
# Out:
#            a         b         c
# 0   0.488135  2.151894  1.027634
# 1   0.448832 -0.763452  1.458941
# 2  -0.624128  3.917730  4.636628
# 3  -1.165585  2.917250  0.288949
# 4   0.680446  4.255966 -4.289639
# ..       ...       ...       ...
# 95 -3.518591  4.818294 -0.216297
# 96 -0.026086  1.394725 -1.314154
# 97 -3.630997  3.221177 -3.101521
# 98  0.113190 -2.756830 -4.021555
# 99  3.621915  4.729195  4.608347
#
# [100 rows x 3 columns]
# <Axes: ylabel='Density'>
